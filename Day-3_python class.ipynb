# %%
Continuation to string datatypes :

# %%
fullname = 'koushik hanan'

print(fullname)
# Out:
# koushik hanan

# %%
print(fullname.title())
# Out:
# Koushik Hanan

# %%
# I want the entere name in capital letters

# %%
print(fullname.upper())
# Out:
# KOUSHIK HANAN

# %%
# I want the entere name in small letters

# %%
print(fullname.lower())
# Out:
# koushik hanan

# %%
Introduction of f strings :

# %%
# General syntax of f strings

# %%
message = f"custom message { placeholder_1} {placeholder_2}............{placeholder_n}"

# %%
firstname = "koushik"
lastname = "hanan"

# %%
# req : i want to get the full name :

# %%
fullname = f"{firstname} {lastname}"

print(fullname)
# Out:
# koushik hanan

# %%
message = f"keep up the good work, {fullname.title()}"
print(message)
# Out:
# keep up the good work, Koushik Hanan

# %%
Adding whitespace to the strings :

# %%
# req: I want to conduct a survey among a group of students to choose their favourite programming language.......

# %%
print("fav_programing:pythonjavaC++openswiftsql")
# Out:
# fav_programing:pythonjavaC++openswiftsql

# %%
# \n  new line delimiter

# %%
print("fav_programing:\npython\njava\nC++\nopenswift\nsql")
# Out:
# fav_programing:
# python
# java
# C++
# openswift
# sql

# %%
# \t tab delimiter

# %%
print("fav_programing:\n\tpython\n\tjava\n\tC++\n\topenswift\n\tsql")
# Out:
# fav_programing:
# 	python
# 	java
# 	C++
# 	openswift
# 	sql

# %%
# removing whitespaces from the strings :

# %%
name1 = "python"

print(name1)
# Out:
# python

# %%
name2 = "   python"     # # here the gap is on the left side

print(name2)
# Out:
#    python

# %%
name3 = "python    "   # here the gap is on the right side

print(name3)
# Out:
# python

# %%
print(name2.lstrip())   # left stripping             # This is called stripping
# Out:
# python

# %%
name2.lstrip()
# Out:
# 'python'

# %%
name3.rstrip()
# Out:
# 'python'
