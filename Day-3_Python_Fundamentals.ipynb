# %%
continuation with string data type :

# %%
Introduction to string methods :

# %%
name = 'vijay'

print(name)
# Out:
# vijay

# %%
# req: I want to know what kind of data type it is?

# %%
type(name)  # str ----> string datatype
# Out:
# str

# %%
name2 = "Ajith"

print(name2)
# Out:
# Ajith

# %%
type(name2) # str -----> string datatype
# Out:
# str

# %%
fullname = 'koushik hanan'

print(fullname)
# Out:
# koushik hanan

# %%
print(fullname.title())
# Out:
# Koushik Hanan

# %%
# i want to get the full name in capital case Letters...?

# %%
print(fullname.upper())
# Out:
# KOUSHIK HANAN

# %%
# i want to get the full name in small case Letters...?

# %%
print(fullname.lower())
# Out:
# koushik hanan

# %%
adding whitespaces to the string :

# %%
# req :

# %%
print("fav_programming:pythonCjavaC++swiftcobal") # output its not good? no clarity
# Out:
# fav_programming:pythonCjavaC++swiftcobal

# %%
print("fav_programming:\npython\nCjava\nC++\nswift\ncobal")  # \n ---> new line delimiter (Ex : printing new line)
# Out:
# fav_programming:
# python
# Cjava
# C++
# swift
# cobal

# %%
print("fav_programming:\n\tpython\n\tCjava\n\tC++\n\tswift\n\tcobal") #\t ----> tab delimiter
# Out:
# fav_programming:
# 	python
# 	Cjava
# 	C++
# 	swift
# 	cobal
