# %%
print("hellow world!!")
# Out:
# hellow world!!

# %%
# shift + enter button on the keyboard

# %%
Introduction to Python Programming

# %%
Understanding the variables in Python:

# %%
a = 5

b = 10

# %%
c = a+b
print(c)
# Out:
# 15

# %%
Rules for declaring the variables

# %%
Rule No 1 : no namespaces for declaring the variables

# %%
firstname = "Vijay"

print(firstname)
# Out:
# Vijay

# %%
first_name = "Vijay"

print(first_name)
# Out:
# Vijay

# %%
first name = 'vijay'

print(first name)
# Out:
#   Cell In[12], line 1
#     first name = 'vijay'
#           ^
# SyntaxError: invalid syntax

# %%
Role No 2: A Variable name should not start with a number put **

# %%
1name = 'chip'

print(1name)
# Out:
#   Cell In[13], line 1
#     1name = 'chip'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'chip'

print(name1)
# Out:
# chip

# %%
Role no 3 : A variable name should not contain any special charactors

# %%
! @ # $ % & *

# %%
name@ = 'matthew'

print(name@)
# Out:
#   Cell In[15], line 1
#     name@ = 'matthew'
#           ^
# SyntaxError: invalid syntax

# %%
name = 'matthew'

print(name)
# Out:
# matthew

# %%
Introduction to Datatypes in python :

1. Strings ----> str
2. Numbers ----> integers ( int ) and float (decimals 0,1,0.2)
3. lists   -----> list
4. tuples ---> tuple
5. dictionaries ----> dict

# %%
Note Python is a case-sensitive programming language ... Ex no caps

# %%
Classification of datatypes :
    Broadly, datatypes are classified into two categories 

    1. mutable datatypes ------> which we can edit/alter ---> flexible in nature.

    2. immutable datatypes -----> which we cannot be able to edit ----> fixed in nature.

# %%
Introduction to string datatypes :

# %%
Definition: A string is nothing but a series of characters declared in quotes.

Classification: It is classified as an immutable datatype

How to define the string? -----> two types of approaches:
    1. single quote 
    2. double quote

# %%
name = 'Ajith'

print(name)
# Out:
# Ajith

# %%
name = "Vijay"

print(name)
# Out:
# Vijay
