# %% [raw]
# # continuation with list data type :

# %%
students = ['vijay','swapna','david','rahil','ayesha','akhila']

# %%
print(students)
# Out:
# ['vijay', 'swapna', 'david', 'rahil', 'ayesha', 'akhila']

# %% [raw]
# # req : i want to print swapna name in the output? what is the index number should i use?

# %%
print(students[1].title())
# Out:
# Swapna

# %% [raw]
# # Req : how to delete the elements from the list

# %% [raw]
# # I want to delete David's name from the list.?

# %%
del students[2]  # perment deleting....

# %%
print(students)
# Out:
# ['vijay', 'swapna', 'rahil', 'ayesha', 'akhila']

# %% [raw]
# # tempvery deleting -----------> pop method

# %% [raw]
# pop method by default it will be deleting the last value from the list....

# %%
x = students.pop()

# %%
print(students)
# Out:
# ['vijay', 'swapna', 'rahil', 'ayesha']

# %%
print(x)
# Out:
# akhila

# %% [raw]
# # Interview question: What is the difference between the delete and pop methods in a list? Can you pls explain ?

# %% [raw]
# # Organising the list data type:

# %%
cars = ('suzuki','hyundai','benz','kia','bmw','mahendra','audi')

# %%
print(cars)
# Out:
# ('suzuki', 'hyundai', 'benz', 'kia', 'bmw', 'mahendra', 'audi')

# %% [raw]
# # There are 2 approaches :

# %% [raw]
# 1. Permanent approach ---> changes are implied permanently ----> sort
#
# 2. Temporary approach ----> No changes are applied we can have the original order -----> sorted

# %%
print(sorted(cars)) # audi,,,benz,,,h,k  (be, bn)
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'mahendra', 'suzuki']

# %%
print(cars) # This is the original order...
# Out:
# ('suzuki', 'hyundai', 'benz', 'kia', 'bmw', 'mahendra', 'audi')

# %% [raw]
# # Interview question: What is the difference between the sorted and sort methods in the list data type?

# %% [raw]
# # req: I want to print the entire list in the reverse order?

# %%
cars.reverse()

# %%
print(cars)
# Out:
# ('suzuki', 'hyundai', 'benz', 'kia', 'bmw', 'mahendra', 'audi')

# %%
cars[::-1]
# Out:
# ('audi', 'mahendra', 'bmw', 'kia', 'benz', 'hyundai', 'suzuki')

# %%
sorted(cars)
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'mahendra', 'suzuki']

# %%
cars.reverse[]

# %%
print(cars)
# Out:
# ('suzuki', 'hyundai', 'benz', 'kia', 'bmw', 'mahendra', 'audi')
