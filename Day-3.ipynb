# %% [markdown]
# # Introduction to list datatpe :

# %% [markdown]
# # Definition: A list is a collection of items declared in a particular order.
#
# # Classification: It is classified as a mutable data type
#
# # How to define a list data type ----> []

# %%
students = ['vijay','ajith','suriya','vikram','rajini','kamal']

# %%
print(students)
# Out:
# ['vijay', 'ajith', 'suriya', 'vikram', 'rajini', 'kamal']

# %% [markdown]
# # Understanding the concept of indexing: 0,1,2,3,4............

# %% [markdown]
# # How to access the elements in the above list ....?

# %% [markdown]
# # req: I want to access Vijay's name from the above list ...?

# %%
print(students[0])
# Out:
# vijay

# %%
print(students[0].title())
# Out:
# Vijay

# %% [markdown]
# # req: i want to access suriya name in the output... what is the index no?

# %%
print(students[2].title())
# Out:
# Suriya

# %% [markdown]
# 1. How to add new elements to the above list?
#
# 2. How to modify the elements in the list?
#
# 3. How to delete elements from the list?

# %% [markdown]
# # Arya --- I want to add Arya name to the list?

# %%
students.append('arya')

# %%
print(students)
# Out:
# ['vijay', 'ajith', 'suriya', 'vikram', 'rajini', 'kamal', 'arya']

# %% [markdown]
# Nayathara --- I want to add Nayanthara name to the list?

# %%
students.append('nayanthara')

# %%
print(students)
# Out:
# ['vijay', 'ajith', 'suriya', 'vikram', 'rajini', 'kamal', 'arya', 'nayanthara']

# %% [markdown]
# Trisha - i want to add trisha to the 1st index position?

# %%
students.insert(1,'trisha')

# %%
print(students)
# Out:
# ['vijay', 'trisha', 'trisha', 'ajith', 'suriya', 'vikram', 'rajini', 'kamal', 'arya', 'nayanthara']

# %%
1. interview question : what is the difference between append and insert method in the list datatype
