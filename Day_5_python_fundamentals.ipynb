# %% [markdown]
# # Continuation with list datatype :

# %% [markdown]
# # Slicing the list

# %% [markdown]
# 1 General syntax of slicing
#
# 2 (Start_value:Stop_value:Stop_count) # The last value is always exclusive; to include the stop value, we have to increase the index by +1

# %% [markdown]
# # (Start_value:Stop_value:Stop_count)

# %%
students = ['Akhila','Jeevitha','Dinesh','Rahul','Anish','Mohit']

# %%
print(students)
# Out:
# ['Akhila', 'Jeevitha', 'Dinesh', 'Rahul', 'Anish', 'Mohit']

# %%
print(students[0:1])
# Out:
# ['Akhila']

# %%
print(students[0:2])
# Out:
# ['Akhila', 'Jeevitha']

# %%
print(students[2:4])
# Out:
# ['Dinesh', 'Rahul']

# %%
print(students[4:6])
# Out:
# ['Anish', 'Mohit']

# %%
print(students[0:6:2])
# Out:
# ['Akhila', 'Dinesh', 'Anish']

# %% [markdown]
# # Introduction to looping statement :

# %% [markdown]
# # Introduction to the for loop :

# %% [raw]
# # General syntax of a for loop :

# %%
for tempvar in mainvar:      # tempvar is x,a # Mainvar is students  
    print(tempvar)

# %%
print(students)
# Out:
# ['Akhila', 'Jeevitha', 'Dinesh', 'Rahul', 'Anish', 'Mohit']

# %%
message = f"Keep up the good work, {students[0].title()}"
print(message)
# Out:
# Keep up the good work, Akhila

# %%
message = f"Keep up the good work, {students[2].title()}"
print(message)
# Out:
# Keep up the good work, Dinesh

# %%
for x in students:
    print(x)
# Out:
# Akhila
# Jeevitha
# Dinesh
# Rahul
# Anish
# Mohit

# %%
for x in students:
    print(f"Keep up the good work,{x.title()}")
# Out:
# Keep up the good work,Akhila
# Keep up the good work,Jeevitha
# Keep up the good work,Dinesh
# Keep up the good work,Rahul
# Keep up the good work,Anish
# Keep up the good work,Mohit

# %%
for a in students:
    print(f"Keep up the good work,{a.title()}")
# Out:
# Keep up the good work,Akhila
# Keep up the good work,Jeevitha
# Keep up the good work,Dinesh
# Keep up the good work,Rahul
# Keep up the good work,Anish
# Keep up the good work,Mohit

# %%
for a in students:          #IndentationError means no space before print (Interview Question)
print(f"Keep up the good work,{a.title()}")
# Out:
#   Cell In[29], line 2
#     print(f"Keep up the good work,{a.title()}")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
for a in students:
    print(f"Keep up the good work,{a.title()}")
    print(f"Do submit the work tiday,{a.title()}")
# Out:
# Keep up the good work,Akhila
# Do submit the work tiday,Akhila
# Keep up the good work,Jeevitha
# Do submit the work tiday,Jeevitha
# Keep up the good work,Dinesh
# Do submit the work tiday,Dinesh
# Keep up the good work,Rahul
# Do submit the work tiday,Rahul
# Keep up the good work,Anish
# Do submit the work tiday,Anish
# Keep up the good work,Mohit
# Do submit the work tiday,Mohit

# %%
for a in students:
    print(f"Keep up the good work,{a.title()}")
    print(f"Do submit the work tiday,{a.title()}\n")
# Out:
# Keep up the good work,Akhila
# Do submit the work tiday,Akhila
#
# Keep up the good work,Jeevitha
# Do submit the work tiday,Jeevitha
#
# Keep up the good work,Dinesh
# Do submit the work tiday,Dinesh
#
# Keep up the good work,Rahul
# Do submit the work tiday,Rahul
#
# Keep up the good work,Anish
# Do submit the work tiday,Anish
#
# Keep up the good work,Mohit
# Do submit the work tiday,Mohit
